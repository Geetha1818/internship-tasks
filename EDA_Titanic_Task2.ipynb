# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset (Titanic dataset from seaborn)
df = sns.load_dataset('titanic')

# 1. Show first 5 rows
print("First 5 rows of data:")
print(df.head())

# 2. Show basic info
print("\nDataset Info:")
print(df.info())

# 3. Show basic stats
print("\nSummary Statistics:")
print(df.describe(include='all'))

# 4. Check missing values
print("\nMissing Values:")
print(df.isnull().sum())

# 5. Value counts of target column (survived)
print("\nSurvival Count:")
print(df['survived'].value_counts())

# 6. Plot: Countplot of Survival
sns.countplot(data=df, x='survived')
plt.title('Survival Count')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()

# 7. Plot: Survival by Sex
sns.countplot(data=df, x='sex', hue='survived')
plt.title('Survival by Sex')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# 8. Plot: Age distribution
plt.hist(df['age'].dropna(), bins=30)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
# Out:
# First 5 rows of data:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ...

# %%
# Check missing values in each column
print(df.isnull().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# Title and Conclusion - (Comments ga add chesanu code lo)

# ## Conclusion
# - Majority of passengers did not survive.
# - Females had higher survival rate than males.
# - Younger passengers had better chance of survival.

# Show first 5 rows of dataset
print("First 5 rows of Titanic dataset:")
print(df.head())

# Check missing values before handling
print("\nMissing values before handling:")
print(df.isnull().sum())

# Handle missing values
df['age'] = df['age'].fillna(df['age'].mean())  # Fill age missing values with mean
df.dropna(inplace=True)  # Drop rows with other missing values

# Check missing values after handling
print("\nMissing values after handling:")
print(df.isnull().sum())
# Out:
# First 5 rows of Titanic dataset:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
#
# Missing values before handling:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# ...

# %%
# Fill missing 'age' values with average age
df['age'] = df['age'].fillna(df['age'].mean())

# Drop rows with missing values in other columns (if any)
df.dropna(inplace=True)

# Check again after handling missing data
print(df.isnull().sum())
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64
